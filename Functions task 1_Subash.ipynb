# %%
 def add_numbers(a,b):
  return a + b

# %%
  num = add_numbers(7,4)
  print("sum:", num)
# Out:
# sum: 11

# %%
def find_max(a,b):
  if a > b:
    return a
  else:
      return b

# %%
num = find_max(7,4)
print("max:", num)
# Out:
# max: 7

# %%
def square(num):
  return num ** 2

# %%
result = square(10)
print("square:", result)
# Out:
# square: 100

# %%
def is_even(num):
  return num % 2 == 0

# %%
print(is_even(12))
print(is_even(10))
# Out:
# True
# True

# %%
def concatenate_strings(str1, str2):
  return str1 + str2

# %%
result = concatenate_strings("Subash", "Gnanavel")
print(result)
# Out:
# SubashGnanavel
